# %%
import os
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
print("Hadoop Version:", spark._jvm.org.apache.hadoop.util.VersionInfo.getVersion())
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# WARNING: package sun.security.action not in java.base
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/02 15:55:52 WARN Utils: Your hostname, Macsens-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.100.133.74 instead (on interface en0)
# 26/03/02 15:55:52 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/02 15:55:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# WARNING: A terminally deprecated method in sun.misc.Unsafe has been called
# WARNING: sun.misc.Unsafe::allocateMemory has been called by io.netty.util.internal.PlatformDependent0$2 (file:/Users/macsenhiggins/VSCodeProjects/CS4265_NYC_Taxi_Project/.venv/lib/python3.13/site-packages/pyspark/jars/netty-common-4.2.7.Final.jar)
# WARNING: Please consider reporting this to the maintainers of class io.netty.util.internal.PlatformDependent0$2
# WARNING: sun.misc.Unsafe::allocateMemory will be removed in a future release
# Hadoop Version: 3.4.2
